# %% [markdown]
# # CineVision Studios
# ## Análisis Exploratorio
#
# Fabiola Contreras, 22787
# María José Villafuerte, 22129

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import scipy.stats as stats
import statsmodels.stats.diagnostic as diag
import statsmodels.api as sm
import seaborn as sns
from collections import Counter

# %% [markdown]
# Lectura de datos de CSV

# %%
datos=pd.read_csv("movies.csv", encoding="latin1")

# %% [markdown]
# ## Análisis de variables

# %%
# Variables cuantitativas
columnas_cuantitativas = datos.select_dtypes(include=['float64', 'int64']).columns.tolist()

# Variables cualitativas
columnas_cualitativas = datos.select_dtypes(include=['object', 'category']).columns.tolist()

# %% [markdown]
# ### Exploración rápida

# %%
# NUMERO DE DATOS
print(f"Número de datos: {len(datos)}")

# TIPO DE VARIABLES 
print("Data Types:")
print(datos.dtypes)

# VALORES QUE FALTAN
print("Valores faltantes :")
print(datos.isnull().sum())

# TODAS LAS COLUMNAS
print(datos.columns)
x =0
for cumon in datos.columns:
  x=x+1

print ('Número de columnas = ' + str(x))

# DESCRIPCION GENERAL
print(datos.describe())
# Out:
# Número de datos: 10000
# Data Types:
# id                             int64
# budget                         int64
# genres                        object
# homePage                      object
# productionCompany             object
# productionCompanyCountry      object
# productionCountry             object
# revenue                      float64
# runtime                        int64
# video                         object
# director                      object
# actors                        object
# actorsPopularity              object
# actorsCharacter               object
# originalTitle                 object
# title                         object
# originalLanguage              object
# popularity                   float64
# releaseDate                   object
# voteAvg                      float64
# voteCount                      int64
# genresAmount                   int64
# productionCoAmount             int64
# productionCountriesAmount      int64
# actorsAmount                   int64
# castWomenAmount               object
# castMenAmount                 object
# dtype: object
# Valores faltantes :
# id                              0
# budget                          0
# genres                         53
# homePage                     5807
# productionCompany             457
# productionCompanyCountry     1280
# productionCountry             233
# revenue                         0
# runtime                         0
# video                         486
# director                       74
# actors                         80
# actorsPopularity               87
# actorsCharacter                47
# originalTitle                   0
# title                           0
# originalLanguage                0
# popularity                      0
# releaseDate                     0
# voteAvg                         0
# voteCount                       0
# genresAmount                    0
# productionCoAmount              0
# productionCountriesAmount       0
# actorsAmount                    0
# castWomenAmount                 0
# castMenAmount                   0
# dtype: int64
# Index(['id', 'budget', 'genres', 'homePage', 'productionCompany',
#        'productionCompanyCountry', 'productionCountry', 'revenue', 'runtime',
#        'video', 'director', 'actors', 'actorsPopularity', 'actorsCharacter',
#        'originalTitle', 'title', 'originalLanguage', 'popularity',
#        'releaseDate', 'voteAvg', 'voteCount', 'genresAmount',
#        'productionCoAmount', 'productionCountriesAmount', 'actorsAmount',
#        'castWomenAmount', 'castMenAmount'],
#       dtype='object')
# Número de columnas = 27
#                   id        budget       revenue       runtime    popularity  \
# count   10000.000000  1.000000e+04  1.000000e+04  10000.000000  10000.000000
# mean   249876.829300  1.855163e+07  5.673793e+07    100.268100     51.393907
# std    257380.109004  3.662669e+07  1.495854e+08     27.777829    216.729552
# min         5.000000  0.000000e+00  0.000000e+00      0.000000      4.258000
# 25%     12286.500000  0.000000e+00  0.000000e+00     90.000000     14.577750
# 50%    152558.000000  5.000000e+05  1.631245e+05    100.000000     21.905500
# 75%    452021.750000  2.000000e+07  4.479661e+07    113.000000     40.654000
# max    922260.000000  3.800000e+08  2.847246e+09    750.000000  11474.647000
#
#             voteAvg     voteCount  genresAmount  productionCoAmount  \
# count  10000.000000  10000.000000  10000.000000        10000.000000
# mean       6.483490   1342.381800      2.596500            3.171400
# std        0.984274   2564.196637      1.154565            2.539738
# min        1.300000      1.000000      0.000000            0.000000
# 25%        5.900000    120.000000      2.000000            2.000000
# 50%        6.500000    415.000000      3.000000            3.000000
# 75%        7.200000   1316.000000      3.000000            4.000000
# max       10.000000  30788.000000     16.000000           89.000000
#
#        productionCountriesAmount   actorsAmount
# count               10000.000000   10000.000000
# mean                    1.751000    2147.666600
# std                     3.012093   37200.075802
# min                     0.000000       0.000000
# 25%                     1.000000      13.000000
# 50%                     1.000000      21.000000
# 75%                     2.000000      36.000000
# max                   155.000000  919590.000000

# %% [markdown]
# Podemos identificar que hay 27 columnas, con la función describe, podemos ver infromación sobre los datos, pero no nos dice mucho, más que el posible promedio de cada una de las variables.
#
# Con Data Type podemos saber que tipo de variables son con las que estaremos trabajando
#
# tenemos un par de datos faltantes en ciertas columnas

# %% [markdown]
# ### Distribuición Normal

# %%
for variabes in columnas_cuantitativas:
    x = datos[[variabes]]
    print(f"\nFrecuencias para {variabes}:")
    plt.hist(x.values)
    plt.title(f'Histograma de {variabes}')
    plt.xlabel(variabes)
    plt.ylabel('Frecuencia')
    sm.qqplot(datos[variabes],line='45')
    stat,p = stats.shapiro(x)
    print(f"¿Sigue una distribución normal? {'Sí' if p >= 0.05 else 'No'}")
    print(f"p-value: {float(p):.3e}")
    plt.tight_layout()
    plt.show()
# Out:
# Frecuencias para id:
# ¿Sigue una distribución normal? No
# p-value: 7.918e-70
# c:\Users\villa\Desktop\Clases_S7\2.Minería de Datos\1.HDT1_datos_cine_estudio\CineVision_Studios\.venv\lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 10000.
#   res = hypotest_fun_out(*samples, **kwds)
# Frecuencias para budget:
# ¿Sigue una distribución normal? No
# p-value: 4.706e-94
# c:\Users\villa\Desktop\Clases_S7\2.Minería de Datos\1.HDT1_datos_cine_estudio\CineVision_Studios\.venv\lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 10000.
#   res = hypotest_fun_out(*samples, **kwds)
# Frecuencias para revenue:
# ¿Sigue una distribución normal? No
# p-value: 1.651e-101
# c:\Users\villa\Desktop\Clases_S7\2.Minería de Datos\1.HDT1_datos_cine_estudio\CineVision_Studios\.venv\lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 10000.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\Users\villa\Desktop\Clases_S7\2.Minería de Datos\1.HDT1_datos_cine_estudio\CineVision_Studios\.venv\lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 10000.
#   res = hypotest_fun_out(*samples, **kwds)
# Frecuencias para runtime:
# ¿Sigue una distribución normal? No
# p-value: 4.642e-70
# Frecuencias para popularity:
# ¿Sigue una distribución normal? No
# p-value: 3.719e-112
# c:\Users\villa\Desktop\Clases_S7\2.Minería de Datos\1.HDT1_datos_cine_estudio\CineVision_Studios\.venv\lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 10000.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\Users\villa\Desktop\Clases_S7\2.Minería de Datos\1.HDT1_datos_cine_estudio\CineVision_Studios\.venv\lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 10000.
#   res = hypotest_fun_out(*samples, **kwds)
# Frecuencias para voteAvg:
# ¿Sigue una distribución normal? No
# p-value: 1.954e-35
# c:\Users\villa\Desktop\Clases_S7\2.Minería de Datos\1.HDT1_datos_cine_estudio\CineVision_Studios\.venv\lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 10000.
#   res = hypotest_fun_out(*samples, **kwds)
# Frecuencias para voteCount:
# ¿Sigue una distribución normal? No
# p-value: 2.615e-96
# c:\Users\villa\Desktop\Clases_S7\2.Minería de Datos\1.HDT1_datos_cine_estudio\CineVision_Studios\.venv\lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 10000.
#   res = hypotest_fun_out(*samples, **kwds)
# Frecuencias para genresAmount:
# ¿Sigue una distribución normal? No
# p-value: 2.644e-61
# Frecuencias para productionCoAmount:
# ¿Sigue una distribución normal? No
# p-value: 2.194e-84
# c:\Users\villa\Desktop\Clases_S7\2.Minería de Datos\1.HDT1_datos_cine_estudio\CineVision_Studios\.venv\lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 10000.
#   res = hypotest_fun_out(*samples, **kwds)
# Frecuencias para productionCountriesAmount:
# ¿Sigue una distribución normal? No
# p-value: 2.514e-108
# c:\Users\villa\Desktop\Clases_S7\2.Minería de Datos\1.HDT1_datos_cine_estudio\CineVision_Studios\.venv\lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 10000.
#   res = hypotest_fun_out(*samples, **kwds)
# Frecuencias para actorsAmount:
# ¿Sigue una distribución normal? No
# p-value: 1.974e-114
# c:\Users\villa\Desktop\Clases_S7\2.Minería de Datos\1.HDT1_datos_cine_estudio\CineVision_Studios\.venv\lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 10000.
#   res = hypotest_fun_out(*samples, **kwds)

# %% [markdown]
# El análisis de las variables cuantitativas revela que ninguna sigue una distribución normal. Si bien algunas variables como Id y VoteAvg exhiben visualmente patrones que se asemejan a una distribución normal, las pruebas estadísticas de normalidad demuestran que no cumplen con los criterios requeridos para ser consideradas normalmente distribuidas.

# %% [markdown]
# ### Tablas de frecuencia

# %%
print(f"\nFrecuencias para {columnas_cualitativas[0]}:")

datos['split'] = datos['genres'].str.split('|')
datos_exploded = datos.explode('split')
tabla_frecuencia = datos_exploded['split'].value_counts()

# Mostrar la tabla de frecuencias
print(tabla_frecuencia)
# Out:
# Frecuencias para genres:
# split
# Drama              3789
# Comedy             3018
# Action             2632
# Thriller           2565
# Adventure          1769
# Horror             1512
# Animation          1460
# Romance            1428
# Family             1407
# Fantasy            1284
# Science Fiction    1267
# Crime              1225
# Mystery             804
# History             406
# Music               315
# Documentary         299
# TV Movie            276
# War                 275
# Western             120
# Name: count, dtype: int64

# %%
print(f"\nFrecuencias para {columnas_cualitativas[1]}:")
print(datos[columnas_cualitativas[1]].value_counts())
# Out:
# Frecuencias para homePage:
# homePage
# http://www.naruto-movie.com/                                                                          6
# http://www.thehungergames.movie/                                                                      4
# http://www.kungfupanda.com/                                                                           3
# http://wwws.warnerbros.co.jp/rurouni-kenshin/index.html                                               3
# http://www.p3m.jp/                                                                                    3
#                                                                                                      ..
# https://www.netflix.com/title/81332722                                                                1
# https://www.paramountplus.com/movies/reno-911-the-hunt-for-qanon/4lSjY6_RqRGLtpUqpgUKWtH2EFZKcmZf/    1
# https://www.netflix.com/title/81478916                                                                1
# https://www.netflix.com/title/81520054                                                                1
# https://www.uphe.com/movies/8-mile                                                                    1
# Name: count, Length: 4125, dtype: int64

# %%
print(f"\nFrecuencias para {columnas_cualitativas[2]}:")
datos['split'] = datos['productionCompany'].str.split('|')
datos_exploded = datos.explode('split')
tabla_frecuencia = datos_exploded['split'].value_counts()

# Mostrar la tabla de frecuencias
print(tabla_frecuencia)
# Out:
# Frecuencias para productionCompany:
# split
# Warner Bros. Pictures                        480
# Universal Pictures                           466
# Columbia Pictures                            347
# Paramount                                    320
# 20th Century Fox                             310
#                                             ...
# King World Entertainment                       1
# Jerry Gershwin Productions                     1
# Íslenska kvikmyndasamsteypan                   1
# Elliott Kastner Productions                    1
# He Nan Dian Ying Dian Shi Zhi Zuo Ji Tuan      1
# Name: count, Length: 10142, dtype: int64

# %%
print(f"\nFrecuencias para {columnas_cualitativas[3]}:")

datos['split'] = datos['productionCompanyCountry'].str.strip().str.split('|')
datos_exploded = datos.explode('split')
tabla_frecuencia = datos_exploded['split'].value_counts()

# Mostrar la tabla de frecuencias
print(tabla_frecuencia)
# Out:
# Frecuencias para productionCompanyCountry:
# split
# US           12675
#               7735
# JP            1604
# FR            1478
# GB            1413
#              ...
# Indonesia        1
# EG               1
# MC               1
# KH               1
# BO               1
# Name: count, Length: 86, dtype: int64

# %%
print(f"\nFrecuencias para {columnas_cualitativas[4]}:")

datos['split'] = datos['productionCountry'].str.split('|')
datos_exploded = datos.explode('split')
tabla_frecuencia = datos_exploded['split'].value_counts()

# Mostrar la tabla de frecuencias
print(tabla_frecuencia)
# Out:
# Frecuencias para productionCountry:
# split
# United States of America    6788
# United Kingdom              1171
# Japan                        731
# France                       668
# Canada                       634
#                             ...
# Bosnia and Herzegovina         1
# Costa Rica                     1
# Estonia                        1
# Antarctica                     1
# Kenya                          1
# Name: count, Length: 111, dtype: int64

# %%
print(f"\nFrecuencias para {columnas_cualitativas[5]}:")
print(datos[columnas_cualitativas[5]].value_counts())
# Out:
# Frecuencias para video:
# video
# False    9430
# True       84
# Name: count, dtype: int64

# %%
print(f"\nFrecuencias para {columnas_cualitativas[6]}:")
print(datos[columnas_cualitativas[6]].value_counts())
# Out:
# Frecuencias para director:
# director
# Steven Spielberg              29
# Clint Eastwood                28
# Ridley Scott                  23
# Martin Scorsese               19
# Steven Soderbergh             19
#                               ..
# Fernando Ayllón                1
# Gray Hofmeyr|Ziggy Hofmeyr     1
# Izu Ojukwu                     1
# Rodrigo Van Der Put            1
# Ale McHaddo                    1
# Name: count, Length: 5330, dtype: int64

# %%
print(f"\nFrecuencias para {columnas_cualitativas[7]}:")
datos['split'] = datos['actors'].str.split('|')
datos_exploded = datos.explode('split')
tabla_frecuencia = datos_exploded['split'].value_counts()

# Mostrar la tabla de frecuencias
print(tabla_frecuencia)
# Out:
# Frecuencias para actors:
# split
# FALSE              480
# Frank Welker       143
# Grey DeLisle        97
# Jeff Bennett        91
# Fred Tatasciore     86
#                   ...
# Mariana Gajá         1
# César Rodríguez      1
# Christian Ramos      1
# 47.619               1
# 18.866               1
# Name: count, Length: 132626, dtype: int64

# %%
print(f"\nFrecuencias para {columnas_cualitativas[9]}:")
datos['split'] = datos['actorsCharacter'].str.split('|')
datos_exploded = datos.explode('split')
tabla_frecuencia = datos_exploded['split'].value_counts()

# Mostrar la tabla de frecuencias
print(tabla_frecuencia)
# Out:
# Frecuencias para actorsCharacter:
# split
#                              4474
# Self                         1723
# Additional Voices (voice)    1566
# Himself                      1445
# Dancer                       1008
#                              ...
# Uncle Owen                      1
# Aunt Beru                       1
# Chief Jawa                      1
# Pawnee #1                       1
# Chaiyut's Girlfriend            1
# Name: count, Length: 164023, dtype: int64

# %%
print(f"\nFrecuencias para {columnas_cualitativas[10]}:")
print(datos[columnas_cualitativas[10]].value_counts())
# Out:
# Frecuencias para originalTitle:
# originalTitle
# Pinocchio                                    4
# Cinderella                                   3
# Les Misérables                               3
# Carrie                                       3
# Prey                                         3
#                                             ..
# Camp Confidential: America's Secret Nazis    1
# Les Rois de l'arnaque                        1
# Beni Çok Sev                                 1
# Puff: Wonders of the Reef                    1
# 14 Peaks: Nothing Is Impossible              1
# Name: count, Length: 9760, dtype: int64

# %%
print(f"\nFrecuencias para {columnas_cualitativas[11]}:")
print(datos[columnas_cualitativas[11]].value_counts())
# Out:
# Frecuencias para title:
# title
# Pinocchio                                       4
# Cinderella                                      4
# Halloween                                       3
# Fallen                                          3
# Godzilla                                        3
#                                                ..
# Lords of Scam                                   1
# Love Me Instead                                 1
# Puff: Wonders of the Reef                       1
# 14 Peaks: Nothing Is Impossible                 1
# Catalina la Catrina: especial Día de Muertos    1
# Name: count, Length: 9697, dtype: int64

# %%
print(f"\nFrecuencias para {columnas_cualitativas[12]}:")
print(datos[columnas_cualitativas[12]].value_counts())
# Out:
# Frecuencias para originalLanguage:
# originalLanguage
# en    7772
# ja     644
# es     425
# fr     271
# ko     167
# zh     119
# it     100
# de      84
# cn      80
# ru      67
# pt      43
# no      28
# sv      27
# hi      27
# da      27
# nl      18
# th      17
# pl      15
# id      12
# tr      10
# fi       8
# tl       5
# te       5
# sr       4
# is       4
# fa       3
# cs       2
# el       2
# ro       2
# uk       2
# nb       1
# bn       1
# he       1
# eu       1
# ms       1
# ar       1
# la       1
# ta       1
# ml       1
# ca       1
# Name: count, dtype: int64

# %%
print(f"\nFrecuencias para {columnas_cualitativas[13]}:")
print(datos[columnas_cualitativas[13]].value_counts())
# Out:
# Frecuencias para releaseDate:
# releaseDate
# 2021-02-12    15
# 2021-10-08    15
# 2021-10-01    14
# 2021-11-12    12
# 2019-11-08    11
#               ..
# 1985-02-20     1
# 2004-12-15     1
# 2000-09-28     1
# 1996-12-12     1
# 2021-08-30     1
# Name: count, Length: 5568, dtype: int64

# %%
print(f"\nFrecuencias para {columnas_cualitativas[14]}:")
print(datos[columnas_cualitativas[14]].value_counts())
# Out:
# Frecuencias para castWomenAmount:
# castWomenAmount
# 3                                                               1055
# 4                                                               1038
# 5                                                                893
# 2                                                                873
# 6                                                                776
#                                                                 ...
# 897243                                                             1
# 899599                                                             1
# 917263                                                             1
# Phantastische Harry Potter Momente - Das große SAT.1 Spezial       1
# 922162                                                             1
# Name: count, Length: 222, dtype: int64

# %%
print(f"\nFrecuencias para {columnas_cualitativas[15]}:")
print(datos[columnas_cualitativas[15]].value_counts())
# Out:
# Frecuencias para castMenAmount:
# castMenAmount
# 7                                                               546
# 10                                                              501
# 8                                                               493
# 9                                                               492
# 5                                                               477
#                                                                ...
# 912223                                                            1
# Making The Witcher: Season 2                                      1
# Phantastische Harry Potter Momente - Das große SAT.1 Spezial      1
# 922017                                                            1
# Five Nights at Freddy's: Home Breach                              1
# Name: count, Length: 612, dtype: int64

# %% [markdown]
# ## Preguntas Clave

# %% [markdown]
# 1.	¿Cuáles son las 10 películas que contaron con más presupuesto?
# 2.	¿Cuáles son las 10 películas que más ingresos tuvieron?
# 3.	¿Cuál es la película que más votos tuvo?
# 4.	¿Cuál es la peor película de acuerdo con los votos de todos los usuarios?
# 5.	¿Cuántas películas se hicieron en cada año? ¿En qué año se hicieron más películas? Haga un gráfico de barras
# 6.	¿Cuál es el género principal de las 20 películas más recientes? ¿Cuál es el género principal que predomina en el conjunto de datos? Represéntelo usando un gráfico.
#         a. ¿A qué género principal pertenecen las películas más largas?
# 7.	¿Las películas de qué genero principal obtuvieron mayores ganancias?
# 8.	¿La cantidad de actores influye en los ingresos de las películas? ¿se han hecho películas con más actores en los últimos años?
# 9.	¿Es posible que la cantidad de hombres y mujeres en el reparto influya en la popularidad y los ingresos de las películas?
# 10.	¿Quiénes son los directores que hicieron las 20 películas mejor calificadas?
# 11.	¿Cómo se correlacionan los presupuestos con los ingresos? ¿Los altos presupuestos
# significan altos ingresos? Haga los gráficos que necesite, histograma, diagrama de
# dispersión
# 12.	¿Se asocian ciertos meses de lanzamiento con mejores ingresos?
# 13.	¿En qué meses se han visto los lanzamientos con mejores ingresos? ¿cuántas películas, en promedio, se han lanzado por mes?
# 14.	¿Cómo se correlacionan las calificaciones con el éxito comercial?
# 15.	¿La popularidad del elenco está directamente correlacionada con el éxito de taquilla?
# 16.	¿Qué estrategias de marketing, como videos promocionales o páginas oficiales, generan mejores resultados?

# %%
print("1.	¿Cuáles son las 10 películas que contaron con más presupuesto?:")
top_budget = datos.nlargest(10, 'budget')[['title', 'budget']]
print(top_budget)
# Out:
# 1.	¿Cuáles son las 10 películas que contaron con más presupuesto?:
#                                             title     budget
# 716   Pirates of the Caribbean: On Stranger Tides  380000000
# 4710                      Avengers: Age of Ultron  365000000
# 5952                            Avengers: Endgame  356000000
# 163      Pirates of the Caribbean: At World's End  300000000
# 4953                               Justice League  300000000
# 5953                       Avengers: Infinity War  300000000
# 607                              Superman Returns  270000000
# 3791                                      Tangled  260000000
# 7134                                The Lion King  260000000
# 280                                  Spider-Man 3  258000000

# %%
print("2. ¿Cuáles son las 10 películas que más ingresos tuvieron?")
top_10_ingresos = datos[['title', 'revenue']].sort_values(by='revenue', ascending=False).head(10)
print(top_10_ingresos)
# Out:
# 2. ¿Cuáles son las 10 películas que más ingresos tuvieron?
#                              title       revenue
# 3210                        Avatar  2.847246e+09
# 5952             Avengers: Endgame  2.797801e+09
# 307                        Titanic  2.187464e+09
# 4947  Star Wars: The Force Awakens  2.068224e+09
# 5953        Avengers: Infinity War  2.046240e+09
# 4914                Jurassic World  1.671713e+09
# 7134                 The Lion King  1.667635e+09
# 9049       Spider-Man: No Way Home  1.631853e+09
# 3397                  The Avengers  1.518816e+09
# 5087                     Furious 7  1.515048e+09

# %%
print('3.	¿Cuál es la película que más votos tuvo?')
masvotada = datos.nlargest(1, 'voteCount')[['title', 'voteCount', 'voteAvg']]
print(masvotada)
# Out:
# 3.	¿Cuál es la película que más votos tuvo?
#           title  voteCount  voteAvg
# 3511  Inception      30788      8.4

# %%
print("4. ¿Cuál es la peor película de acuerdo con los votos de todos los usuarios?")
bottom_10_votes = datos[['title', 'voteAvg']].sort_values(by='voteAvg', ascending=True).head(1)
print(bottom_10_votes)
# Out:
# 4. ¿Cuál es la peor película de acuerdo con los votos de todos los usuarios?
#                                                   title  voteAvg
# 9786  DAKAICHI -I'm Being Harassed by the Sexiest Ma...      1.3

# %%
print('5.	¿Cuántas películas se hicieron en cada año? ¿En qué año se hicieron más películas? Haga un gráfico de barras')
datos['year'] = pd.to_datetime(datos['releaseDate']).dt.year
peliculas_por_year = datos['year'].value_counts().sort_index()

# Quiero que sean dos gráficas para que se visualice mejor asi que busco el punto medio
year = peliculas_por_year.index
medio_year = year[len(year)//2]

# Dividir datos
primera_mitad = peliculas_por_year[peliculas_por_year.index <= medio_year]
segunda_mitad = peliculas_por_year[peliculas_por_year.index > medio_year]

# Crear subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 12))

# Gráfica primera mitad
primera_mitad.plot(kind='bar', ax=ax1)
ax1.set_title(f'Películas por Año ({primera_mitad.index.min()} - {primera_mitad.index.max()})')
ax1.set_xlabel('Año')
ax1.set_ylabel('Número de Películas')
ax1.tick_params(axis='x', rotation=45)

# Gráfica segunda mitad
segunda_mitad.plot(kind='bar', ax=ax2)
ax2.set_title(f'Películas por Año ({segunda_mitad.index.min()} - {segunda_mitad.index.max()})')
ax2.set_xlabel('Año')
ax2.set_ylabel('Número de Películas')
ax2.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# Año con más películas
max_year = peliculas_por_year.idxmax()
cantidad_max = peliculas_por_year.max()

print(f"Año con más películas: {max_year} ({cantidad_max} películas)")
# Out:
# 5.	¿Cuántas películas se hicieron en cada año? ¿En qué año se hicieron más películas? Haga un gráfico de barras
# Año con más películas: 2021 (816 películas)

# %%
print("6. ¿Cuál es el género principal de las 20 películas más recientes?")

# Asegurar que las fechas sean de tipo datetime
datos['releaseDate'] = pd.to_datetime(datos['releaseDate'], errors='coerce')

top_20_recent = datos[['genres', 'releaseDate']].sort_values(by='releaseDate', ascending=False).head(20)
print(top_20_recent)

# Separar géneros y contar frecuencia
todos_los_generos = datos['genres'].dropna().str.split('|').sum()
conteo_generos = pd.Series(Counter(todos_los_generos)).sort_values(ascending=False)

# Graficar distribución de géneros

plt.figure(figsize=(8, 8))
conteo_generos.head(5).plot(kind='pie', autopct='%1.1f%%', colors=['skyblue', 'lightcoral', 'gold', 'lightgreen', 'purple'])
plt.title('Distribución de Géneros (Top 5)')
plt.ylabel('')
plt.show()

print("\n\n¿A qué género principal pertenecen las películas más largas?")
top_5_long = datos[['genres', 'runtime']].sort_values(by='runtime', ascending=False).head(5)
print(top_5_long)
# Out:
# 6. ¿Cuál es el género principal de las 20 películas más recientes?
#                                   genres releaseDate
# 9516                               Drama  2022-01-21
# 9545                        Comedy|Drama  2022-01-19
# 9197                       Drama|Mystery  2022-01-14
# 9808                            Thriller  2022-01-07
# 9586         Action|Thriller|Crime|Drama  2022-01-07
# 9982                         Documentary  2022-01-01
# 9951                        Action|Drama  2022-01-01
# 9257                                 NaN  2021-12-31
# 9241                                 NaN  2021-12-31
# 9866                             Romance  2021-12-31
# 9683  Animation|Adventure|Fantasy|Family  2021-12-30
# 9877             Horror|Thriller|Mystery  2021-12-28
# 9988                              Comedy  2021-12-27
# 9346              Comedy|Romance|Fantasy  2021-12-26
# 9253                               Drama  2021-12-25
# 9996                              Comedy  2021-12-25
# 9479                       Comedy|Horror  2021-12-25
# 9560                       Drama|Fantasy  2021-12-25
# 9170             Action|Adventure|Comedy  2021-12-24
# 9872                      Comedy|Romance  2021-12-24
# ¿A qué género principal pertenecen las películas más largas?
#                      genres  runtime
# 9347            Documentary      750
# 5358            Documentary      400
# 3885      Drama|History|War      333
# 962           Drama|History      317
# 1263  Drama|History|Romance      248

# %%
print('7.	¿Las películas de qué genero principal obtuvieron mayores ganancias?')
datos['main_genre'] = datos['genres'].str.split('|').str[0]

# Promedio de ingresos por género
avg_revenue = datos.groupby('main_genre')['revenue'].mean().sort_values(ascending=False)
print("Ingresos promedio por género principal:")
print(avg_revenue)
# Out:
# 7.	¿Las películas de qué genero principal obtuvieron mayores ganancias?
# Ingresos promedio por género principal:
# main_genre
# Adventure          1.592496e+08
# Action             9.284366e+07
# Fantasy            9.257043e+07
# Science Fiction    8.449515e+07
# Family             7.238093e+07
# War                6.439539e+07
# Animation          5.449281e+07
# Comedy             4.805140e+07
# Mystery            4.462266e+07
# History            4.234144e+07
# Drama              3.683590e+07
# Crime              3.660747e+07
# Music              3.565113e+07
# Thriller           3.094291e+07
# Western            3.022270e+07
# Romance            2.985217e+07
# Horror             2.606378e+07
# Documentary        1.359698e+06
# TV Movie           0.000000e+00
# Name: revenue, dtype: float64

# %%
print("8. ¿La cantidad de actores influye en los ingresos de las películas?")
plt.figure(figsize=(8, 6))
sns.regplot(x=datos['actorsAmount'], y=datos['revenue'], scatter_kws={'alpha': 0.5}, line_kws={"color": "red"})
plt.title('Relación entre cantidad de actores e ingresos')
plt.xlabel('Cantidad de actores')
plt.ylabel('Ingresos')
plt.grid(alpha=0.5)
plt.show()

# Filtrar los datos para actores <= 1000
datos_filtrados = datos[datos['actorsAmount'] <= 1000]

# 📏 Scatter plot con línea de regresión
plt.figure(figsize=(8, 6))
sns.regplot(x=datos_filtrados['actorsAmount'], 
            y=datos_filtrados['revenue'], 
            scatter_kws={'alpha': 0.5}, 
            line_kws={"color": "red"})
plt.title('Relación entre cantidad de actores e ingresos (máx. 1000 actores)')
plt.xlabel('Cantidad de actores')
plt.ylabel('Ingresos')
plt.grid(alpha=0.5)
plt.show()

# Calcular la correlación entre las calificaciones (actorsAmount) y los ingresos (revenue)
correlacion = datos['actorsAmount'].corr(datos['revenue'])

print(f"La correlación entre la cantidad de actores y los ingresos es: {correlacion}")

print("\n¿se han hecho películas con más actores en los últimos años?")
# Convertir releaseDate a tipo datetime (si no lo está)
datos['releaseDate'] = pd.to_datetime(datos['releaseDate'], errors='coerce')

# Extraer el año y agrupar
datos['año'] = datos['releaseDate'].dt.year

df_ultimos_20_años = datos[datos['año'] >= (datos['año'].max() - 24)] 
actors_por_año = df_ultimos_20_años.groupby('año')['actorsAmount'].mean()


# Mostrar los resultados
print(actors_por_año)
# Out:
# 8. ¿La cantidad de actores influye en los ingresos de las películas?
# La correlación entre la cantidad de actores y los ingresos es: -0.019554880174247613
#
# ¿se han hecho películas con más actores en los últimos años?
# año
# 1998      36.706522
# 1999      34.051546
# 2000      31.477273
# 2001      33.147727
# 2002    2668.783784
# 2003      28.281407
# 2004    3032.510917
# 2005      28.416327
# 2006    8338.610294
# 2007      29.770677
# 2008    2853.248227
# 2009    3105.020468
# 2010     314.814332
# 2011    1269.110803
# 2012    2442.167683
# 2013    1870.553398
# 2014    2193.423611
# 2015    1403.093333
# 2016    4111.929982
# 2017    3593.011327
# 2018    3896.748808
# 2019    2107.874183
# 2020    2832.315197
# 2021    3188.525735
# 2022      12.142857
# Name: actorsAmount, dtype: float64

# %%
print('9.	¿Es posible que la cantidad de hombres y mujeres en el reparto influya en la popularidad y los ingresos de las películas?')
datos['castWomenAmount'] = pd.to_numeric(datos['castWomenAmount'], errors='coerce')
datos['castMenAmount'] = pd.to_numeric(datos['castMenAmount'], errors='coerce')

# Crear categorías basadas en la proporción de mujeres
datos['women_proportion'] = datos['castWomenAmount'] / (datos['castWomenAmount'] + datos['castMenAmount'])
datos['gender_category'] = pd.cut(datos['women_proportion'], bins=[0, 0.2, 0.4, 0.6, 0.8, 1], labels=['0-20% mujeres', '20-40% mujeres', '40-60% mujeres', '60-80% mujeres', '80-100% mujeres'])

# Crear subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Boxplot para popularidad
sns.boxplot(data=datos, x='gender_category', y='popularity', ax=ax1)
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45)
ax1.set_title('Distribución de Popularidad por Proporción de Género')
ax1.set_xlabel('Proporción de Mujeres en el Elenco')
ax1.set_ylabel('Popularidad')

# Boxplot para ingresos
sns.boxplot(data=datos, x='gender_category', y='revenue', ax=ax2)
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45)
ax2.set_title('Distribución de Ingresos por Proporción de Género')
ax2.set_xlabel('Proporción de Mujeres en el Elenco')
ax2.set_ylabel('Ingresos')

plt.tight_layout()
plt.show()

# Estadísticas por categoría
print("\nEstadísticas por categoría de género:")
for categoria in datos['gender_category'].unique():
    subset = datos[datos['gender_category'] == categoria]
    print(f"\n{categoria}:")
    print(f"Popularidad promedio: {subset['popularity'].mean():.2f}")
    print(f"Ingresos promedio: {subset['revenue'].mean():.2e}")
    print(f"Cantidad de películas: {len(subset)}")
# Out:
# 9.	¿Es posible que la cantidad de hombres y mujeres en el reparto influya en la popularidad y los ingresos de las películas?
# C:\Users\villa\AppData\Local\Temp\ipykernel_25896\2879174759.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45)
# C:\Users\villa\AppData\Local\Temp\ipykernel_25896\2879174759.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45)
# Estadísticas por categoría de género:
#
# 60-80% mujeres:
# Popularidad promedio: 41.50
# Ingresos promedio: 2.28e+07
# Cantidad de películas: 598
#
# 20-40% mujeres:
# Popularidad promedio: 59.67
# Ingresos promedio: 7.63e+07
# Cantidad de películas: 4158
#
# 0-20% mujeres:
# Popularidad promedio: 40.16
# Ingresos promedio: 6.10e+07
# Cantidad de películas: 1941
#
# 40-60% mujeres:
# Popularidad promedio: 50.82
# Ingresos promedio: 4.36e+07
# Cantidad de películas: 2651
#
# 80-100% mujeres:
# Popularidad promedio: 43.96
# Ingresos promedio: 5.03e+06
# Cantidad de películas: 126
#
# nan:
# Popularidad promedio: nan
# Ingresos promedio: nan
# Cantidad de películas: 0

# %%
print("10. ¿Quiénes son los directores que hicieron las 20 películas mejor calificadas?")

top_20_directors = (
    datos[['director', 'voteAvg']]
    .dropna()  # Elimina filas con NaN en 'director' o 'voteAvg'
    .sort_values(by='voteAvg', ascending=False)
    .head(20)
)

print(top_20_directors)
# Out:
# 10. ¿Quiénes son los directores que hicieron las 20 películas mejor calificadas?
#                                                director  voteAvg
# 9298                                  Laurent Bouzereau     10.0
# 8632                                       Thomas Coven     10.0
# 9246                                      Rebecca Sugar     10.0
# 9733                                     Christin Baker     10.0
# 9084                         Víctor Barba|Juan Olivares     10.0
# 9990                                Miguel Angel Zavala     10.0
# 9347                                       Kaku Arakawa     10.0
# 6885             Dave Bullock|Troy Adomitis|Victor Cook      9.6
# 9368                                     Won Myeong-jun      9.5
# 6170                                       Samuel Leong      9.5
# 5528                                 Selena Quintanilla      9.4
# 9783                                     Haruo Sotozaki      9.3
# 9756                                     Haruo Sotozaki      9.3
# 9451                                       Park Jun-soo      9.2
# 9219  Kim Nam-joon|Jeon Jung-kook|Kim Tae-hyung|Park...      9.2
# 8265                                    Ulises Valencia      9.2
# 9777                                       Igor Kopylov      9.2
# 8884                                       Park Jun-soo      9.1
# 5817                                     Michael Goguen      9.0
# 8226                                     Cybil Richards      9.0

# %%
print ('11.	¿Cómo se correlacionan los presupuestos con los ingresos? ¿Los altos presupuestos significan altos ingresos? Haga los gráficos que necesite, histograma, diagrama de dispersión')

# Calcular correlación
correlation = datos['budget'].corr(datos['revenue'])

# Crear gráfico de dispersión
plt.figure(figsize=(10, 6))
sns.scatterplot(data=datos, x='budget', y='revenue')
plt.title('Presupuesto vs Ingresos')
plt.xlabel('Presupuesto')
plt.ylabel('Ingresos')

# Añadir línea de tendencia
z = np.polyfit(datos['budget'], datos['revenue'], 1)
p = np.poly1d(z)
plt.plot(datos['budget'], p(datos['budget']), "r--", alpha=0.8)

print(f"Correlación entre presupuesto e ingresos: {correlation:.3f}")

plt.show()
# Out:
# 11.	¿Cómo se correlacionan los presupuestos con los ingresos? ¿Los altos presupuestos significan altos ingresos? Haga los gráficos que necesite, histograma, diagrama de dispersión
# Correlación entre presupuesto e ingresos: 0.757

# %%
print("12. ¿Se asocian ciertos meses de lanzamiento con mejores ingresos?")

plt.figure(figsize=(10, 6))
datos['releaseDate'] = pd.to_datetime(datos['releaseDate'])
datos['releaseMonth'] = datos['releaseDate'].dt.month
ingresos_por_mes = datos.groupby('releaseMonth')['revenue'].sum()
sns.lineplot(x=ingresos_por_mes.index, y=ingresos_por_mes.values, marker='o', color='teal')

# Personalización
plt.title('Ingresos totales por mes de lanzamiento')
plt.xlabel('Mes de lanzamiento')
plt.ylabel('Ingresos totales')
plt.xticks(range(13), ['', 'Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun', 'Jul', 'Ago', 'Sep', 'Oct', 'Nov', 'Dic'])
plt.grid(alpha=0.5)
plt.show()
# Out:
# 12. ¿Se asocian ciertos meses de lanzamiento con mejores ingresos?

# %%
print('13.	¿En qué meses se han visto los lanzamientos con mejores ingresos? ¿cuántas películas, en promedio, se han lanzado por mes?')

# Convertir fechas y extraer mes
datos['releaseDate'] = pd.to_datetime(datos['releaseDate'])
datos['month'] = datos['releaseDate'].dt.month

# Análisis por mes
monthly_analysis = (datos.groupby('month')
                   .agg({
                       'revenue': ['mean', 'max', 'count'],
                       'title': lambda x: x[datos.groupby('month')['revenue'].transform('max') == datos['revenue']]
                   }))

# Renombrar columnas
monthly_analysis.columns = ['ingreso_promedio', 'ingreso_maximo', 'cantidad_peliculas', 'pelicula_mas_exitosa']

# Ordenar por ingreso promedio
monthly_analysis_sorted = monthly_analysis.sort_values('ingreso_promedio', ascending=False)

# Convertir meses a nombres
meses = {1:'Enero', 2:'Febrero', 3:'Marzo', 4:'Abril', 5:'Mayo', 6:'Junio', 
         7:'Julio', 8:'Agosto', 9:'Septiembre', 10:'Octubre', 11:'Noviembre', 12:'Diciembre'}

print("Análisis de Meses por Ingresos:")
print("-" * 70)
for idx in monthly_analysis_sorted.index:
    print(f"\nMes: {meses[idx]}")
    print(f"Ingreso promedio: ${monthly_analysis_sorted.loc[idx, 'ingreso_promedio']:,.2f}")
    print(f"Cantidad de películas: {monthly_analysis_sorted.loc[idx, 'cantidad_peliculas']}")
# Out:
# 13.	¿En qué meses se han visto los lanzamientos con mejores ingresos? ¿cuántas películas, en promedio, se han lanzado por mes?
# Análisis de Meses por Ingresos:
# ----------------------------------------------------------------------
#
# Mes: Junio
# Ingreso promedio: $94,747,108.23
# Cantidad de películas: 819
#
# Mes: Mayo
# Ingreso promedio: $87,845,442.00
# Cantidad de películas: 698
#
# Mes: Julio
# Ingreso promedio: $76,028,696.40
# Cantidad de películas: 812
#
# Mes: Diciembre
# Ingreso promedio: $74,358,880.46
# Cantidad de películas: 935
#
# Mes: Noviembre
# Ingreso promedio: $71,492,112.45
# Cantidad de películas: 807
#
# Mes: Abril
# Ingreso promedio: $52,595,653.57
# Cantidad de películas: 696
#
# Mes: Marzo
# Ingreso promedio: $51,115,941.96
# Cantidad de películas: 815
#
# Mes: Febrero
# Ingreso promedio: $42,908,353.31
# Cantidad de películas: 706
#
# Mes: Octubre
# Ingreso promedio: $38,987,332.02
# Cantidad de películas: 1068
#
# Mes: Agosto
# Ingreso promedio: $35,970,079.46
# Cantidad de películas: 913
#
# Mes: Enero
# Ingreso promedio: $33,773,690.83
# Cantidad de películas: 652
#
# Mes: Septiembre
# Ingreso promedio: $31,928,917.36
# Cantidad de películas: 1079

# %%
print("14. ¿Cómo se correlacionan las calificaciones con el éxito comercial?")

plt.figure(figsize=(8, 6))
sns.regplot(x=datos['voteAvg'], y=datos['revenue'], scatter_kws={'alpha': 0.5}, line_kws={"color": "red"})
plt.title('Relación entre calificaciones e ingresos')
plt.xlabel('Promedio calificaciones')
plt.ylabel('Ingresos')
plt.grid(alpha=0.5)
plt.show()

# Calcular la correlación entre las calificaciones (voteAvg) y los ingresos (revenue)
correlacion = datos['voteAvg'].corr(datos['revenue'])

print(f"La correlación entre las calificaciones y los ingresos es: {correlacion}")
# Out:
# 14. ¿Cómo se correlacionan las calificaciones con el éxito comercial?
# La correlación entre las calificaciones y los ingresos es: 0.14126181161900297

# %%
print('15.	¿La popularidad del elenco está directamente correlacionada con el éxito de taquilla?')
# Convertir actorsPopularity a lista de números
datos['avg_actor_popularity'] = datos['actorsPopularity'].str.split('|').apply(
    lambda x: pd.to_numeric(x, errors='coerce').mean() if isinstance(x, list) else None
)

# Calcular correlaciones
corr_pop_revenue = datos['avg_actor_popularity'].corr(datos['revenue'])
corr_pop_popularity = datos['avg_actor_popularity'].corr(datos['popularity'])

print(f"Correlación popularidad del elenco vs ingresos: {corr_pop_revenue:.3f}")
print(f"Correlación popularidad del elenco vs popularidad película: {corr_pop_popularity:.3f}")
# Out:
# 15.	¿La popularidad del elenco está directamente correlacionada con el éxito de taquilla?
# Correlación popularidad del elenco vs ingresos: 0.082
# Correlación popularidad del elenco vs popularidad película: 0.073

# %%
print("16. ¿Qué estrategias de marketing, como videos promocionales o páginas oficiales, generan mejores resultados?")

datos['homePage'] = datos['homePage'].notna()  # Convertir a True si tiene página, False si no

# Calcular métricas promedio
resultados_marketing = datos.groupby(['video', 'homePage'])[['voteAvg', 'popularity', 'revenue']].mean()

# Mostrar resultados
print(resultados_marketing)

# Graficar comparación de revenue entre grupos
plt.figure(figsize=(8, 5))
resultados_marketing['revenue'].plot(kind='bar', color=['skyblue', 'orange'])
plt.xlabel('Estrategia de Marketing (Video, Página Web)')
plt.ylabel('Ingreso Promedio ($)')
plt.title('Impacto de Marketing en Revenue')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# 16. ¿Qué estrategias de marketing, como videos promocionales o páginas oficiales, generan mejores resultados?
#                  voteAvg  popularity       revenue
# video homePage
# False False     6.365944   35.138868  3.142091e+07
#       True      6.606258   67.393214  7.775714e+07
# True  False     7.513333   39.042000  4.237015e+05
#       True      7.691667   60.595333  7.128291e+05
